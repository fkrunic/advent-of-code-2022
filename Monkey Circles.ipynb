# %% [markdown]
# # Monkey Circles

# %% [markdown]
# **Proposition.** Let $\{(f_i, p_i, c_{(1, i)}, c_{(2, i)})\}_{i = 1}^n$ be a series of tuples where $f_k: \mathbb{N} \to \mathbb{N}$, $p_k$ is a prime number, and $1 \leq c_{(\cdot, i)} \leq n$ with $c_1 \neq c_2$ for any index $i$.  Now, consider a number $q \in \mathbb{N}$.
